# %% [markdown]
# Test video feed

# %%
import cv2
cap=cv2.VideoCapture(0)

while True:
    ret,frame=cap.read()

    if not ret:
        break
    cv2.imshow('video feed',frame)
    
    if cv2.waitKey(1)==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@6720.962] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@6721.166] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %% [markdown]
# Detect Face

# %%
cap=cv2.VideoCapture(0)

face_detector=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

while True:
    ret,frame=cap.read()
    if not ret:
        break
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=face_detector.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.imshow('video feed',frame)

    if cv2.waitKey(1)==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@28.859] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@28.859] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %%
def verify_image(image_path, present_embeddings):
    
    cap=cv2.VideoCapture(0)

    face_detector=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

    while True:
        ret,frame=cap.read()
        if not ret:
            break
        gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        faces=face_detector.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5)
        faces=cv2.resize(faces,160,160)

        for (x,y,w,h) in faces:
            cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)

        cv2.imshow('video feed',frame)

        if cv2.waitKey(1)==ord('q'):
            break

   
        
    # Assuming image is already 160x160 cropped face
    claim_embedding= get_embedding(frame)
    print(claim_embedding)
    # Compare to present embeddings
    min_dist = float('inf')
    for i,present_embedding in enumerate(present_embeddings):
        dist = np.linalg.norm(claim_embedding - present_embedding)
        print(f'distance to embedding {i} is {dist}')
        if dist < min_dist:
            min_dist = dist
    
    result = "Present" if min_dist < 1 else "Not Present"
    print(f'minimum distanc {min_dist}')
    print(result)
    
   
    cv2.rectangle(frame, (0, 0), (160, 160), (0, 255, 0), 2)  
    cv2.putText(frame, result, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    cv2.imshow("Verification Result", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


present_folder = 'Tdataset'
present_embeddings = create_embedding(present_folder)
print(f"Total embeddings: {len(present_embeddings)}")
image_path = ['cropped_dataset/p/jafer/20240419_180120_face3007.jpg',]

for i in image_path:
    verify_image(i, present_embeddings)

# %% [markdown]
# Crop Face to be appropriate for facenet model 160X160

# %%
import os

os.chdir('/home/cs/Desktop/Project/Computer_Vision_Based_Attendance')

# %%
import os

face_detector=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
input_dir='dataset'
output_dir='cropped_dataset'


if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for person in os.listdir(input_dir):
    person_input=os.path.join(input_dir,person)
    person_output=os.path.join(output_dir,person)

    
    
    for img_file in os.listdir(person_input):
        img_path=os.path.join(person_input,img_file)
        img=cv2.imread(img_path)
        gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

        face=face_detector.detectMultiScale(gray,1.1,5)
        if len(face)>0:
            x,y,w,h = face[0]
            face=img[y:y+h,x:x+w]
            face=cv2.resize(face,(160,160))
            output_path=os.path.join(person_output,img_file)
            cv2.imwrite(output_path,face)
print('face cropped')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[8], line 17
#      12 person_input=os.path.join(input_dir,person)
#      13 person_output=os.path.join(output_dir,person)
# ---> 17 for img_file in os.listdir(person_input):
#      18     img_path=os.path.join(person_input,img_file)
#      19     img=cv2.imread(img_path)
#
# NotADirectoryError: [Errno 20] Not a directory: 'dataset/main.py'

# %%
import os

# %%
import os
import cv2


face_detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


input_dir = 'dataset'
output_dir = 'cropped_dataset'


if not os.path.exists(output_dir):
    os.makedirs(output_dir)


for person in os.listdir(input_dir):
    person_input = os.path.join(input_dir, person)
    

    if not os.path.isdir(person_input):
        continue

    person_output = os.path.join(output_dir, person)

    
    if not os.path.exists(person_output):
        os.makedirs(person_output)

    # Loop through each image file for that person
    for img_file in os.listdir(person_input):
        img_path = os.path.join(person_input, img_file)

        # Check if the current item is a file
        if not os.path.isfile(img_path):
            continue

        img = cv2.imread(img_path)

       
        if img is None:
            print(f"Skipping {img_file} as it cannot be read.")
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Detect faces in the image
        faces = face_detector.detectMultiScale(gray, 1.1, 5)

        # If faces are detected, crop and save them
        if len(faces) > 0:
            x, y, w, h = faces[0]
            face = img[y:y + h, x:x + w]
            face = cv2.resize(face, (160, 160))  # Resize the face to 160x160
            output_path = os.path.join(person_output, img_file)
            cv2.imwrite(output_path, face)
        else:
            print(f"No face detected in {img_file}, skipping.")

print('Face cropping process completed.')
# Out:
# Face cropping process completed.

# %%
pip install mtcnn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached mtcnn-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Crop face from group image

# %%
import os
import cv2

# Load the Haar Cascade face detector
face_detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Define input and output directories
input_dir = 'dataset'
output_dir = 'cropped_dataset'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each person in the input directory
for person in os.listdir(input_dir):
    person_input = os.path.join(input_dir, person)

    # Skip if it's not a directory (e.g., it's a file like main.py)
    if not os.path.isdir(person_input):
        continue

    person_output = os.path.join(output_dir, person)

    # Create the person's output directory if it doesn't exist
    if not os.path.exists(person_output):
        os.makedirs(person_output)

    # Loop through each image file for that person
    for img_file in os.listdir(person_input):
        img_path = os.path.join(person_input, img_file)

        # Check if the current item is a file
        if not os.path.isfile(img_path):
            continue

        img = cv2.imread(img_path)

        # Check if the image was loaded successfully
        if img is None:
            print(f"Skipping {img_file} as it cannot be read.")
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Detect faces in the image (this detects multiple faces)
        faces = face_detector.detectMultiScale(gray, 1.1, 5)

        # If faces are detected, crop and save them
        if len(faces) > 0:
            for i, (x, y, w, h) in enumerate(faces):
                face = img[y:y + h, x:x + w]  # Crop the face region
                face = cv2.resize(face, (160, 160))  # Resize the face to 160x160

                # Save each cropped face with a unique name
                output_path = os.path.join(person_output, f"{img_file.split('.')[0]}_face{i+1}.jpg")
                cv2.imwrite(output_path, face)
        else:
            print(f"No faces detected in {img_file}, skipping.")

print('Face cropping process completed.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 47
#      44 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      46 # Detect faces in the image (this detects multiple faces)
# ---> 47 faces = face_detector.detectMultiScale(gray, 1.1, 5)
#      49 # If faces are detected, crop and save them
#      50 if len(faces) > 0:
#
# KeyboardInterrupt:

# %% [markdown]
# Better way to crop face from group image uscin mtcnn

# %%
import os
import cv2
from mtcnn import MTCNN


detector = MTCNN()


input_dir = 'dataset/f'  
output_dir = 'cropped_dataset/feleke'  

if not os.path.exists(output_dir):
    os.makedirs(output_dir)


for person in os.listdir(input_dir):
    person_input = os.path.join(input_dir, person)

    
    if not os.path.isdir(person_input):
        continue

    person_output = os.path.join(output_dir, person)

    
    if not os.path.exists(person_output):
        os.makedirs(person_output)

    
    for img_file in os.listdir(person_input):
        img_path = os.path.join(person_input, img_file)

        
        if not os.path.isfile(img_path):
            continue

        img = cv2.imread(img_path)

        
        if img is None:
            print(f"Skipping {img_file} as it cannot be read.")
            continue

        # Detect faces using MTCNN
        faces = detector.detect_faces(img)

        # If faces are detected, crop and save them
        if len(faces) > 0:
            for i, face in enumerate(faces):
                x, y, w, h = face['box']  # Get the face coordinates
                face_img = img[y:y + h, x:x + w]  # Crop the face
                face_img = cv2.resize(face_img, (160, 160))  # Resize the face to 160x160

                
                output_path = os.path.join(person_output, f"{img_file.split('.')[0]}_face{i}.jpg")
                cv2.imwrite(output_path, face_img)
        else:
            print(f"No faces detected in {img_file}, skipping.")

print('Face cropping process completed.')
# Out:
# 2025-03-10 14:51:50.938989: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17587360 exceeds 10% of free system memory.
# 2025-03-10 14:51:52.101248: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17587360 exceeds 10% of free system memory.
# 2025-03-10 14:51:52.112381: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17587360 exceeds 10% of free system memory.
# 2025-03-10 14:51:52.444130: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 13728896 exceeds 10% of free system memory.
# 2025-03-10 14:51:52.474224: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 13728896 exceeds 10% of free system memory.
# ...
# 1/1 [==============================] - 0s 35ms/step
# Face cropping process completed.

# %%
import tensorflow as tf
import numpy as np

model='20180402-114759.pb'
with tf.Graph().as_default():
    with open(model,'rb') as f:
        graph_def=tf.compat.v1.GraphDef.FromString(f.read())
    tf.import_graph_def(graph_def,name='')
session = tf.compat.v1.Session()
images_input = session.graph.get_tensor_by_name("input:0")
embeddings_output = session.graph.get_tensor_by_name("embeddings:0")
phase_train = session.graph.get_tensor_by_name("phase_train:0")
# Out:
# 2025-03-10 22:37:32.658440: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-10 22:37:54.676540: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-10 22:37:54.766131: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-10 22:38:20.802561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import tensorflow.compat.v1 as tf
import cv2
tf.disable_v2_behavior()

# Load the FaceNet model and graph
with tf.gfile.GFile('20180402-114759.pb', 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())

# Load the graph
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    session = tf.compat.v1.Session(graph=graph)

    # Access the input/output tensors
    images_input = session.graph.get_tensor_by_name("input:0")
    embeddings_output = session.graph.get_tensor_by_name("embeddings:0")
    phase_train = session.graph.get_tensor_by_name("phase_train:0")
# Out:
# 2025-03-10 18:36:00.824575: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-10 18:36:06.911077: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-10 18:36:06.921927: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-10 18:36:19.309542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/cs/.local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
import os
import numpy as np

# %%
def load_image(file_path):
    img=cv2.imread(file_path)
    return img

# %%
def get_embedding(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (160, 160))
    img = (img / 255.0 - 0.5) * 2.0
    img = np.expand_dims(img, axis=0)  

    embedding = session.run(tf.convert_to_tensor(embeddings_output, dtype=tf.float32), feed_dict={
        images_input: img,
        phase_train: False
    })
    

    if embedding.shape[0] == 1:
        print(f'em{embedding[0]}')
        return embedding[0]  
    else:
        return embedding[0, :]

# %%
def create_embedding(folder_path):
    face_detector=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
    embeddings=[]

    for person in os.listdir(folder_path):
        person_path=os.path.join(folder_path,person)
        print(f'person path{person_path}')
        if os.path.isdir(person_path):
            person_embedding=[]
            for photo in os.listdir(person_path):
                photo_path=os.path.join(person_path,photo)
                print(f'photo path {photo_path}')
                img=load_image(photo_path)
                if img is None:
                    print(f'failed to load {photo_path}')
                gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                faces=face_detector.detectMultiScale(gray,1.1,5)
                if len(faces)>0:
                    x,y,w,h=faces[0]
                    face=img[y:y+h,x:x+w]
                    print(face)
                    embedding=get_embedding(face)
                    print(embedding)
                    person_embedding.append(embedding)
                else:
                    print(f'No face in {photo_path}')
        if person_embedding:
            avg_embedding=np.mean(person_embedding,axis=0)
            embeddings.append(avg_embedding)
            print(f'embbeding created for {person}')
    return embeddings

folder_path='Tdataset'
embeddings_output=create_embedding(folder_path)
print(embeddings_output)
# Out:
# person pathTdataset/ezedin
# photo path Tdataset/ezedin/20240419_181723_face11.jpg
# No face in Tdataset/ezedin/20240419_181723_face11.jpg
# photo path Tdataset/ezedin/20240419_181729_face18.jpg
# No face in Tdataset/ezedin/20240419_181729_face18.jpg
# photo path Tdataset/ezedin/20240419_181548_face9.jpg
# No face in Tdataset/ezedin/20240419_181548_face9.jpg
# photo path Tdataset/ezedin/photo_5841381442590987247_y_face3000.jpg
# No face in Tdataset/ezedin/photo_5841381442590987247_y_face3000.jpg
# photo path Tdataset/ezedin/photo_5841381442590987241_y_face3001.jpg
# No face in Tdataset/ezedin/photo_5841381442590987241_y_face3001.jpg
# photo path Tdataset/ezedin/photo_5841381442590987243_y_face3001.jpg
# [[[ 5  2  4]
#   [ 8  5  7]
#   [ 8  6 12]
#   ...
#   [20 17 32]
#   [16 14 26]
#   [12  8 20]]
#
#  [[ 7  4  6]
#   [10  7  9]
#   [10  8 14]
#   ...
#   [27 24 40]
#   [22 19 34]
#   [17 15 27]]
#
#  [[ 9  6  8]
#   [12  9 11]
#   [12 11 15]
#   ...
#   [32 30 49]
#   [29 26 42]
# ...

# %%
import tensorflow.compat.v1 as tf
import cv2
import os
import numpy as np

tf.disable_v2_behavior()

# Load FaceNet model
with tf.gfile.GFile('20180402-114759.pb', 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())

graph = tf.Graph()
with graph.as_default():
    tf.import_graph_def(graph_def, name='')
    session = tf.compat.v1.Session(graph=graph)

images_input = graph.get_tensor_by_name("input:0")
embeddings_output = graph.get_tensor_by_name("embeddings:0")
phase_train = graph.get_tensor_by_name("phase_train:0")

def load_image(file_path):
    img = cv2.imread(file_path)
    if img is None:
        raise ValueError(f"Could not load image at {file_path}")
    return img

def get_embedding(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = (img / 255.0 - 0.5) * 2.0  
    img = np.expand_dims(img, axis=0)
    embedding = session.run(embeddings_output, feed_dict={
        images_input: img,
        phase_train: False
    })
    print(f"Embedding: {embedding[0][:5]}...")  
    return embedding[0]

def create_embedding(folder_path):
    embeddings = []
    for person in os.listdir(folder_path):
        person_path = os.path.join(folder_path, person)
        print(f"Person path: {person_path}")
        if os.path.isdir(person_path):
            person_embedding = []
            for photo in os.listdir(person_path):
                photo_path = os.path.join(person_path, photo)
                print(f"Photo path: {photo_path}")
                try:
                    img = load_image(photo_path)
                    embedding = get_embedding(img)
                    person_embedding.append(embedding)
                except Exception as e:
                    print(f"Failed to process {photo_path}: {e}")
            if person_embedding:
                avg_embedding = np.mean(person_embedding, axis=0)
                embeddings.append(avg_embedding)
                print(f"Embedding created for {embeddings}")
    np.save('embeddings',embeddings)
    return embeddings

folder_path = 'Tdataset'
embeddings_output = create_embedding(folder_path)
# print(f"Total persons with embeddings: {len(embeddings_output)}")
# for i, emb in enumerate(embeddings_output):
#     print(f"Person {i} embedding: {emb[:5]}... (shape: {emb.shape})")
# Out:
# 2025-03-11 19:29:32.805631: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-11 19:29:37.089224: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-11 19:29:37.097025: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-11 19:29:46.353634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/cs/.local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# def verify_live_cam(present_embeddings):
#     cap = cv2.VideoCapture(0)  # Open webcam
#     face_detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    
#     while True:
#         ret, frame = cap.read()  # Get frame
#         if not ret:
#             print("Failed to access webcam")
#             break
#         frame=cv2.imread('Tdataset/feleke/photo_5933665171497141373_y_face3000.jpg')
#         faces= cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#         faces=cv2.resize(gray,160,160)
#        # faces = face_detector.detectMultiScale(gray, 1.1, 5)
        
#         for (x, y, w, h) in faces:
#             face = frame[y:y+h, x:x+w]
#             claim_embedding = get_embedding(face)
            
#             # Compare to present embeddings
#             min_dist = 100
#             for present_embedding in present_embeddings:
#                 dist = np.linalg.norm(claim_embedding - present_embedding)
#                 if dist < min_dist:
#                     min_dist = dist
            
#                     if min_dist < 1.2:
#                         print("Present") 
#                     else:
#                         print("Not Present")
#     #         cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
#     #         cv2.putText(frame, result, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        
#     #     cv2.imshow("Party Verification", frame)
#     #     if cv2.waitKey(1) == ord('q'):  # Quit with 'q'
#     #         break
    
#     # cap.release()
#     # cv2.destroyAllWindows()

# # Run the full system
# present_folder = 'Tdataset'
# present_embeddings = create_embedding(present_folder)
# print(f"Total embeddings: {len(present_embeddings)}")
# verify_live_cam(present_embeddings)
# Out:
# Person path: Tdataset/abel gezu
# Photo path: Tdataset/abel gezu/IMG_8142_face3002.jpg
# Embedding: [-0.02462943 -0.00477117 -0.0383881   0.0877642  -0.01053893]...
# Photo path: Tdataset/abel gezu/IMG_8239_face3000.jpg
# Embedding: [-0.02308235  0.00312175 -0.01736182  0.09786963 -0.03550561]...
# Photo path: Tdataset/abel gezu/20240419_175057_face2.jpg
# Embedding: [ 0.00213678  0.00829811 -0.02545333  0.09006491 -0.02246968]...
# Photo path: Tdataset/abel gezu/IMG_8240_face3001.jpg
# Embedding: [-0.01958076 -0.00600055 -0.01625586  0.09367585 -0.02452578]...
# Photo path: Tdataset/abel gezu/IMG_8140_face3000.jpg
# Embedding: [-0.02613613 -0.0036355  -0.03253046  0.07849814 -0.00544161]...
# Photo path: Tdataset/abel gezu/IMG_8137_face3001.jpg
# Embedding: [-0.01857939  0.00402282 -0.02382888  0.09365387 -0.02437561]...
# Photo path: Tdataset/abel gezu/IMG_8139_face3000.jpg
# Embedding: [-0.01521372  0.0060447  -0.02943036  0.09547939 -0.01070167]...
# ...

# %%
def verify_image(image_path,present_embeddings):
    frame = cv2.imread(image_path)
    if frame is None:
        print(f"Failed to load image: {image_path}")
        return
    
    # Assuming image is already 160x160 cropped face
    claim_embedding= get_embedding(frame)
    print(claim_embedding)
    # Compare to present embeddings
    min_dist = float('inf')
    for i,present_embedding in enumerate(present_embeddings):
        dist = np.linalg.norm(claim_embedding - present_embedding)
        print(f'distance to embedding {i} is {dist}')
        if dist < min_dist:
            min_dist = dist
    
    result = "Present" if min_dist < 1 else "Not Present"
    print(f'minimum distanc {min_dist}')
    print(result)
    
   
    cv2.rectangle(frame, (0, 0), (160, 160), (0, 255, 0), 2)  
    cv2.putText(frame, result, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    cv2.imshow("Verification Result", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


present_folder = 'Tdataset'
present_embeddings = create_embedding(present_folder)
print(f"Total embeddings: {len(present_embeddings)}")
image_path = ['Tdataset/cse keeper/photo_5841400108518850849_y_face3001.jpg',]

for i in image_path:
    verify_image(i, present_embeddings)
# Out:
# Person path: Tdataset/cse keeper
# Photo path: Tdataset/cse keeper/jafer
# Failed to process Tdataset/cse keeper/jafer: Could not load image at Tdataset/cse keeper/jafer
# Photo path: Tdataset/cse keeper/20240419_174635_face14.jpg
# Embedding: [-0.00442302 -0.06232953 -0.04689667  0.00096048 -0.01350463]...
# Photo path: Tdataset/cse keeper/photo_5841400108518850851_y_face3001.jpg
# Embedding: [ 0.0074398  -0.03755473 -0.08178994  0.03929864 -0.00201669]...
# Photo path: Tdataset/cse keeper/20240419_173512_face3007.jpg
# Embedding: [ 0.00945505 -0.0338832  -0.01541324  0.02714559 -0.04098909]...
# Photo path: Tdataset/cse keeper/20240419_173534_face3001.jpg
# Embedding: [-0.00126975  0.00988547 -0.00577551  0.01791202 -0.01747009]...
# Photo path: Tdataset/cse keeper/20240419_173617_face3001.jpg
# Embedding: [-0.00416346 -0.00953967 -0.00129011  0.00404144 -0.04389105]...
# Photo path: Tdataset/cse keeper/20240419_174936_face3006.jpg
# ...

# %%
present_folder = 'Tdataset'
present_embeddings = create_embedding(present_folder)
# Out:
# Person path: Tdataset/abel gezu
# Photo path: Tdataset/abel gezu/IMG_8142_face3002.jpg
# 2025-03-11 02:23:25.186820: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# Embedding: [-0.02462943 -0.00477117 -0.0383881   0.0877642  -0.01053893]...
# Photo path: Tdataset/abel gezu/IMG_8239_face3000.jpg
# Embedding: [-0.02308235  0.00312175 -0.01736182  0.09786963 -0.03550561]...
# Photo path: Tdataset/abel gezu/20240419_175057_face2.jpg
# Embedding: [ 0.00213678  0.00829811 -0.02545333  0.09006491 -0.02246968]...
# Photo path: Tdataset/abel gezu/IMG_8240_face3001.jpg
# Embedding: [-0.01958076 -0.00600055 -0.01625586  0.09367585 -0.02452578]...
# Photo path: Tdataset/abel gezu/IMG_8140_face3000.jpg
# Embedding: [-0.02613613 -0.0036355  -0.03253046  0.07849814 -0.00544161]...
# Photo path: Tdataset/abel gezu/IMG_8137_face3001.jpg
# Embedding: [-0.01857939  0.00402282 -0.02382888  0.09365387 -0.02437561]...
# ...

# %%
x={'a':[]}
x['a'].append(1)
x
# Out:
# {'a': [1]}

# %% [markdown]
# Loading embedding where it saved

# %%
def load_embedding(saved_path):
    if os.path.exists(saved_path):
        embedding=np.load(saved_path,allow_pickle=True).tolist()
        print(f'loaded embedding from {saved_path}')
        return embedding
    else:
        print(f'not saved embedding at {saved_path}')
